# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## Rydder dataen

# %%
# Leser data
local_path = '/Users/ellajohnsen/Documents/GitHub/NAV/fiktivt_kursdatasett.csv'
client_data = pd.read_csv(local_path)

client_data.sample(5)
# Out:
#         ID jobb_etter_6mnd         utdanning sykdom_siste_aar  \
# 5257  3626             Nei         VGS fullf              Nei
# 7453   396             Nei    VGS ikke fullf               Ja
# 3962  2851              Ja         VGS fullf              Nei
# 3480  8399              Ja  Høyere utd u4 år              Nei
# 8201  1168             Nei               NaN               Ja
#
#      arbsoker_siste_aar forerkort arbeid_siste_2mnd  alder     fylke  \
# 5257                 Ja       Nei               Nei     29  Nordland
# 7453                 Ja       Nei               Nei     34  Buskerud
# 3962                Nei        Ja               Nei     25      Oslo
# 3480                Nei       Nei               Nei     35   Østfold
# 8201                Nei        Ja               Nei     49  Akershus
#
#                              yrke   kjonn
# 5257                  Kontoryrker    Mann
# 7453                  Kontoryrker    Mann
# 3962                  Kontoryrker    Mann
# 3480      Salg, service og omsorg    Mann
# 8201  Renholdere og hjelpepleiere  Kvinne

# %%
utdanning = client_data['utdanning']

# %% [markdown]
# For å forenkle datasettet litt setter jeg 1 = Ja, 2 = Nei og 1 = Kvinne, 0 = Mann

# %%
client_data = client_data.replace(to_replace='Ja', value=1)
client_data = client_data.replace(to_replace='Nei', value=0)
client_data = client_data.replace(to_replace='Kvinne', value=1)
client_data = client_data.replace(to_replace='F', value=1)
client_data = client_data.replace(to_replace='Mann', value=0)
client_data = client_data.replace(to_replace='M', value=0)

client_data[["kjonn"]] = client_data[["kjonn"]].apply(pd.to_numeric)


client_data.sample(5)
# Out:
#         ID  jobb_etter_6mnd         utdanning  sykdom_siste_aar  \
# 6235   251                0         VGS fullf                 0
# 5803   609                1         VGS fullf                 0
# 1573   920                1  Høyere utd u4 år                 0
# 3745  1544                1               NaN                 0
# 5426  7457                0    VGS ikke fullf                 0
#
#       arbsoker_siste_aar  forerkort  arbeid_siste_2mnd  alder  \
# 6235                   1          0                  0     39
# 5803                   0          1                  1     49
# 1573                   0          1                  1     24
# 3745                   0          1                  1     24
# 5426                   0          0                  0     27
#
#                 fylke                          yrke  kjonn
# 6235        Hordaland       Salg, service og omsorg      0
# 5803  Møre og Romsdal                   Håndverkere      0
# 1573    Sør-Trøndelag  Maskin og transportarbeidere      1
# 3745             Oslo                        Ledere      0
# 5426         Nordland                         Annet      0

# %%
client_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8822 entries, 0 to 8821
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  8822 non-null   int64
#  1   jobb_etter_6mnd     8822 non-null   int64
#  2   utdanning           7640 non-null   object
#  3   sykdom_siste_aar    8822 non-null   int64
#  4   arbsoker_siste_aar  8822 non-null   int64
#  5   forerkort           8822 non-null   int64
#  6   arbeid_siste_2mnd   8822 non-null   int64
#  7   alder               8822 non-null   int64
#  8   fylke               8822 non-null   object
#  9   yrke                8822 non-null   object
#  10  kjonn               8822 non-null   int64
# dtypes: int64(8), object(3)
# memory usage: 758.3+ KB

# %%
client_data[['jobb_etter_6mnd', 'sykdom_siste_aar', 'arbsoker_siste_aar', 
            'forerkort', 'arbeid_siste_2mnd', 'alder', 'kjonn']].describe()
# Out:
#        jobb_etter_6mnd  sykdom_siste_aar  arbsoker_siste_aar    forerkort  \
# count      8822.000000       8822.000000         8822.000000  8822.000000
# mean          0.391181          0.268873            0.250283     0.399229
# std           0.488042          0.443399            0.433201     0.489768
# min           0.000000          0.000000            0.000000     0.000000
# 25%           0.000000          0.000000            0.000000     0.000000
# 50%           0.000000          0.000000            0.000000     0.000000
# 75%           1.000000          1.000000            1.000000     1.000000
# max           1.000000          1.000000            1.000000     1.000000
#
#        arbeid_siste_2mnd        alder        kjonn
# count        8822.000000  8822.000000  8822.000000
# mean            0.397982    38.012582     0.399909
# std             0.489510   106.454696     0.489907
# min             0.000000    18.000000     0.000000
# 25%             0.000000    30.000000     0.000000
# 50%             0.000000    36.000000     0.000000
# 75%             1.000000    43.000000     1.000000
# max             1.000000  9999.000000     1.000000

# %% [markdown]
# Maks alder kan ikke være 9999 år så undersøker det

# %%
test = client_data.nlargest(5, ['alder'])
test.sample(5)
# Out:
#         ID  jobb_etter_6mnd       utdanning  sykdom_siste_aar  \
# 503   1950                1             NaN                 0
# 646   5822                0  VGS ikke fullf                 1
# 4885   505                0  VGS ikke fullf                 1
# 395   8031                0             NaN                 0
# 229   4653                0      Grunnskole                 0
#
#       arbsoker_siste_aar  forerkort  arbeid_siste_2mnd  alder       fylke  \
# 503                    0          1                  0     60  Vest-Agder
# 646                    0          1                  0     60  Vest-Agder
# 4885                   0          0                  0   9999     Oppland
# 395                    1          0                  0     60    Vestfold
# 229                    0          0                  1     60    Vestfold
#
#                      yrke  kjonn
# 503           Kontoryrker      0
# 646                Ledere      0
# 4885  Bønder, fiskere, mv      0
# 395                 Annet      1
# 229                Ledere      0

# %%
# Fjerner datapunktet 4885
client_data = client_data.drop([4885])

test = client_data.nlargest(5, ['alder'])
test.sample(5)
# Out:
#        ID  jobb_etter_6mnd         utdanning  sykdom_siste_aar  \
# 503  1950                1               NaN                 0
# 229  4653                0        Grunnskole                 0
# 646  5822                0    VGS ikke fullf                 1
# 395  8031                0               NaN                 0
# 811  3172                1  Høyere utd u4 år                 0
#
#      arbsoker_siste_aar  forerkort  arbeid_siste_2mnd  alder       fylke  \
# 503                   0          1                  0     60  Vest-Agder
# 229                   0          0                  1     60    Vestfold
# 646                   0          1                  0     60  Vest-Agder
# 395                   1          0                  0     60    Vestfold
# 811                   0          0                  0     60      Ukjent
#
#                  yrke  kjonn
# 503       Kontoryrker      0
# 229            Ledere      0
# 646            Ledere      0
# 395             Annet      1
# 811  Akademiske yrker      0

# %%
client_data[['jobb_etter_6mnd', 'sykdom_siste_aar', 'arbsoker_siste_aar', 
            'forerkort', 'arbeid_siste_2mnd', 'alder', 'kjonn']].describe()
# Out:
#        jobb_etter_6mnd  sykdom_siste_aar  arbsoker_siste_aar    forerkort  \
# count      8821.000000       8821.000000         8821.000000  8821.000000
# mean          0.391225          0.268790            0.250312     0.399274
# std           0.488052          0.443356            0.433217     0.489777
# min           0.000000          0.000000            0.000000     0.000000
# 25%           0.000000          0.000000            0.000000     0.000000
# 50%           0.000000          0.000000            0.000000     0.000000
# 75%           1.000000          1.000000            1.000000     1.000000
# max           1.000000          1.000000            1.000000     1.000000
#
#        arbeid_siste_2mnd        alder        kjonn
# count        8821.000000  8821.000000  8821.000000
# mean            0.398027    36.883347     0.399955
# std             0.489519     9.112343     0.489916
# min             0.000000    18.000000     0.000000
# 25%             0.000000    30.000000     0.000000
# 50%             0.000000    36.000000     0.000000
# 75%             1.000000    43.000000     1.000000
# max             1.000000    60.000000     1.000000

# %%
# Prosent sjanse for at man er i jobb etter seks måneder
client_data.jobb_etter_6mnd.sum() / len(client_data.jobb_etter_6mnd)
# Out:
# 0.3912254846389298

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# Ser bort fra utdanning, fylke og yrke da det blir mange forskjellige labels men er absolutt noe man egentlig bør ha med

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, make_scorer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import seaborn as sns

# %%
y = client_data['jobb_etter_6mnd'].copy()      # target variable

features = ['sykdom_siste_aar', 'arbsoker_siste_aar', 'forerkort', 'arbeid_siste_2mnd', 'alder', 'kjonn']
X = client_data[features].copy()

# %%
# Splitting into test and training set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# Checking that the split is ok

print(client_data.jobb_etter_6mnd.describe())
print("---------------------------")
print(y_train.describe())
print("---------------------------")
print(y_test.describe())
# Out:
# count    8821.000000
# mean        0.391225
# std         0.488052
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: jobb_etter_6mnd, dtype: float64
# ---------------------------
# count    7056.000000
# mean        0.390448
# std         0.487885
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: jobb_etter_6mnd, dtype: float64
# ---------------------------
# count    1765.000000
# mean        0.394334
# std         0.488846
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: jobb_etter_6mnd, dtype: float64

# %%
classifier = DecisionTreeClassifier(max_depth=10, random_state=14) 
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)

accuracy_score(y_true = y_test, y_pred = predictions)
# Out:
# 0.7439093484419264

# %%
pd.DataFrame(
    confusion_matrix(y_test, predictions),
    columns=['Predikert arbeidsledig', 'Predikert ansettelse'],
    index=['Reel arbeidsledig', 'Reel ansettelse']
)
# Out:
#                    Predikert arbeidsledig  Predikert ansettelse
# Reel arbeidsledig                     865                   204
# Reel ansettelse                       248                   448

# %%
def feature_plot(features):
    tmp = pd.DataFrame({'Feature': features, 'Feature importance': classifier.feature_importances_})
    tmp = tmp.sort_values(by='Feature importance',ascending=False)
    plt.figure(figsize = (10,4))
    plt.title('Features importance',fontsize=14)
    s = sns.barplot(x='Feature',y='Feature importance',data=tmp)
    s.set_xticklabels(s.get_xticklabels(),rotation=90)
    plt.show()

# %%
feature_plot(features)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
NUM_ESTIMATORS = 100 #number of estimators used for RandomForrestClassifier
NO_JOBS = 4 #number of parallel jobs used for RandomForrestClassifier
RANDOM_STATE = 2018

# %%
classifier = RandomForestClassifier(n_jobs=NO_JOBS, 
                             random_state=RANDOM_STATE,
                             criterion=RFC_METRIC,
                             n_estimators=NUM_ESTIMATORS,
                             verbose=False)
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)

accuracy_score(y_true = y_test, y_pred = predictions)
# Out:
# 0.75014164305949

# %%
feature_plot(features)

# %%
pd.DataFrame(
    confusion_matrix(y_test, predictions),
    columns=['Predikert arbeidsledig', 'Predikert ansettelse'],
    index=['Reel arbeidsledig', 'Reel ansettelse']
)
# Out:
#                    Predikert arbeidsledig  Predikert ansettelse
# Reel arbeidsledig                     871                   198
# Reel ansettelse                       243                   453
